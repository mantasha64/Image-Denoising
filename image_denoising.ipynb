# %%
import numpy as np
from keras.datasets import mnist

# %%
(X_train , _) ,(X_test, _) = mnist.load_data()
X_train.shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# (60000, 28, 28)

# %%
from matplotlib import pyplot as plt
fig, axes = plt.subplots(2,10, figsize = (16, 4))

count = 0

for i in range(2):
    for j in range(10):
        axes[i,j].imshow(X_train[count], cmap = 'gray')
        count+=1

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %%
noise_factor = 0.1

X_train_noise = X_train + noise_factor * np.random.normal(loc = 0., scale = 1., size = X_train.shape)
X_test_noise = X_test + noise_factor * np.random.normal(loc = 0., scale = 1., size = X_test.shape)

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
#visualize noisy data
fig, axes = plt.subplots(2,10, figsize = (16,4))

count = 0
for i in range(2):
    for j in range(10):
        axes[i,j].imshow(X_train_noise[count], cmap = 'gray')
        count+=1

# %%
$reshape dataset
X_train = X_train.reshape(X_train.shape[0], 28 ,28, 1)
X_test = X_test.reshape(X_test.shape[0], 28,28,1)

X_train_noise = X_train_noise.reshape(X_train_noise.shape[0], 28 ,28, 1)
X_test_noise = X_test_noise.reshape(X_test_noise.shape[0], 28,28,1)

X_train.shape, X_train_noise.shape
# Out:
# ((60000, 28, 28, 1), (60000, 28, 28, 1))

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPool2D, Dense, UpSampling2D, BatchNormalization
from keras.callbacks import ModelCheckpoint

import tensorflow as tf

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print(physical_devices)
if physical_devices:
  tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# []

# %%
#encoder
encoder_input = Input(shape = X_train.shape[1:])
x = Conv2D(32, (3,3), activation = 'relu', padding = 'same')(encoder_input)
x = BatchNormalization()(x)
x = MaxPool2D(pool_size = (2,2), padding = 'same')(x)
x = Conv2D(32, (3,3), activation = 'relu', padding = 'same')(x)
x = BatchNormalization()(x)
encoded = MaxPool2D(pool_size = (2,2), padding = 'same')(x)

# %%
# decoder
x = Conv2D(32, (3,3), activation = 'relu', padding = 'same')(encoded)
x = BatchNormalization()(x)
x = UpSampling2D()(x)
x = Conv2D(32, (3,3), activation = 'relu', padding = 'same')(x)
x = BatchNormalization()(x)
x = UpSampling2D()(x)
decoded = Conv2D(1, (3,3), activation = 'sigmoid', padding = 'same')(x)

# %%
autoencoder = Model(encoder_input, decoded, name = 'Denoising_Model')
autoencoder.summary()
# Out:
# Model: "Denoising_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  batch_normalization (Batch  (None, 28, 28, 32)        128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        9248
#
#  batch_normalization_1 (Bat  (None, 14, 14, 32)        128
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 32)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 32)          9248
#
#  batch_normalization_2 (Bat  (None, 7, 7, 32)          128
#  chNormalization)
#
#  up_sampling2d (UpSampling2  (None, 14, 14, 32)        0
#  D)
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 32)        9248
#
#  batch_normalization_3 (Bat  (None, 14, 14, 32)        128
#  chNormalization)
#
#  up_sampling2d_1 (UpSamplin  (None, 28, 28, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 1)         289
#
# =================================================================
# Total params: 28865 (112.75 KB)
# Trainable params: 28609 (111.75 KB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________

# %%
autoencoder.compile(loss = 'binary_crossentropy', optimizer = 'adam')

# %%
checkpoint = ModelCheckpoint("denoising_model.h5", save_best_only=True, save_weights_only=False, verbose = 1)
history = autoencoder.fit(X_train_noise, X_train, batch_size = 128, epochs = 50, callbacks = checkpoint, validation_split = 0.25, verbose = 2)
# Out:
# Epoch 1/50
#
# Epoch 1: val_loss improved from inf to 0.11108, saving model to denoising_model.h5
# 352/352 - 119s - loss: 0.1581 - val_loss: 0.1111 - 119s/epoch - 338ms/step
# Epoch 2/50
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss improved from 0.11108 to 0.08749, saving model to denoising_model.h5
# 352/352 - 105s - loss: 0.0760 - val_loss: 0.0875 - 105s/epoch - 297ms/step
# Epoch 3/50
#
# Epoch 3: val_loss improved from 0.08749 to 0.07515, saving model to denoising_model.h5
# 352/352 - 105s - loss: 0.0733 - val_loss: 0.0751 - 105s/epoch - 298ms/step
# Epoch 4/50
#
# Epoch 4: val_loss improved from 0.07515 to 0.07164, saving model to denoising_model.h5
# 352/352 - 106s - loss: 0.0718 - val_loss: 0.0716 - 106s/epoch - 301ms/step
# Epoch 5/50
#
# Epoch 5: val_loss improved from 0.07164 to 0.07106, saving model to denoising_model.h5
# 352/352 - 105s - loss: 0.0710 - val_loss: 0.0711 - 105s/epoch - 297ms/step
# Epoch 6/50
#
# Epoch 6: val_loss improved from 0.07106 to 0.07031, saving model to denoising_model.h5
# 352/352 - 106s - loss: 0.0703 - val_loss: 0.0703 - 106s/epoch - 302ms/step
# Epoch 7/50
#
# Epoch 7: val_loss did not improve from 0.07031
# 352/352 - 103s - loss: 0.0699 - val_loss: 0.0704 - 103s/epoch - 294ms/step
# Epoch 8/50
#
# Epoch 8: val_loss improved from 0.07031 to 0.07002, saving model to denoising_model.h5
# 352/352 - 104s - loss: 0.0694 - val_loss: 0.0700 - 104s/epoch - 297ms/step
# Epoch 9/50
#
# Epoch 9: val_loss did not improve from 0.07002
# 352/352 - 103s - loss: 0.0691 - val_loss: 0.0723 - 103s/epoch - 293ms/step
# Epoch 10/50
#
# Epoch 10: val_loss did not improve from 0.07002
# 352/352 - 103s - loss: 0.0688 - val_loss: 0.0720 - 103s/epoch - 293ms/step
# Epoch 11/50
#
# Epoch 11: val_loss improved from 0.07002 to 0.06895, saving model to denoising_model.h5
# 352/352 - 103s - loss: 0.0686 - val_loss: 0.0690 - 103s/epoch - 293ms/step
# Epoch 12/50
#
# Epoch 12: val_loss did not improve from 0.06895
# 352/352 - 103s - loss: 0.0684 - val_loss: 0.0691 - 103s/epoch - 292ms/step
# Epoch 13/50
#
# Epoch 13: val_loss did not improve from 0.06895
# 352/352 - 103s - loss: 0.0682 - val_loss: 0.0693 - 103s/epoch - 292ms/step
# Epoch 14/50
#
# Epoch 14: val_loss improved from 0.06895 to 0.06887, saving model to denoising_model.h5
# 352/352 - 101s - loss: 0.0680 - val_loss: 0.0689 - 101s/epoch - 288ms/step
# Epoch 15/50
#
# Epoch 15: val_loss did not improve from 0.06887
# 352/352 - 101s - loss: 0.0680 - val_loss: 0.0699 - 101s/epoch - 288ms/step
# Epoch 16/50
#
# Epoch 16: val_loss improved from 0.06887 to 0.06823, saving model to denoising_model.h5
# 352/352 - 102s - loss: 0.0679 - val_loss: 0.0682 - 102s/epoch - 289ms/step
# Epoch 17/50
#
# Epoch 17: val_loss improved from 0.06823 to 0.06806, saving model to denoising_model.h5
# 352/352 - 105s - loss: 0.0677 - val_loss: 0.0681 - 105s/epoch - 299ms/step
# Epoch 18/50
#
# Epoch 18: val_loss improved from 0.06806 to 0.06799, saving model to denoising_model.h5
# 352/352 - 102s - loss: 0.0676 - val_loss: 0.0680 - 102s/epoch - 290ms/step
# Epoch 19/50
#
# Epoch 19: val_loss did not improve from 0.06799
# 352/352 - 102s - loss: 0.0675 - val_loss: 0.0683 - 102s/epoch - 290ms/step
# Epoch 20/50
#
# Epoch 20: val_loss did not improve from 0.06799
# 352/352 - 101s - loss: 0.0675 - val_loss: 0.0680 - 101s/epoch - 288ms/step
# Epoch 21/50
#
# Epoch 21: val_loss did not improve from 0.06799
# 352/352 - 102s - loss: 0.0673 - val_loss: 0.0691 - 102s/epoch - 288ms/step
# Epoch 22/50
#
# Epoch 22: val_loss did not improve from 0.06799
# 352/352 - 102s - loss: 0.0673 - val_loss: 0.0689 - 102s/epoch - 289ms/step
# Epoch 23/50
#
# Epoch 23: val_loss improved from 0.06799 to 0.06767, saving model to denoising_model.h5
# 352/352 - 102s - loss: 0.0672 - val_loss: 0.0677 - 102s/epoch - 290ms/step
# Epoch 24/50
#
# Epoch 24: val_loss improved from 0.06767 to 0.06760, saving model to denoising_model.h5
# 352/352 - 101s - loss: 0.0670 - val_loss: 0.0676 - 101s/epoch - 287ms/step
# Epoch 25/50
#
# Epoch 25: val_loss improved from 0.06760 to 0.06737, saving model to denoising_model.h5
# 352/352 - 101s - loss: 0.0670 - val_loss: 0.0674 - 101s/epoch - 287ms/step
# Epoch 26/50
#
# Epoch 26: val_loss did not improve from 0.06737
# 352/352 - 102s - loss: 0.0670 - val_loss: 0.0678 - 102s/epoch - 289ms/step
# Epoch 27/50
#
# Epoch 27: val_loss did not improve from 0.06737
# 352/352 - 101s - loss: 0.0669 - val_loss: 0.0674 - 101s/epoch - 288ms/step
# Epoch 28/50
#
# Epoch 28: val_loss improved from 0.06737 to 0.06735, saving model to denoising_model.h5
# 352/352 - 101s - loss: 0.0668 - val_loss: 0.0674 - 101s/epoch - 288ms/step
# Epoch 29/50
#
# Epoch 29: val_loss improved from 0.06735 to 0.06726, saving model to denoising_model.h5
# 352/352 - 102s - loss: 0.0668 - val_loss: 0.0673 - 102s/epoch - 289ms/step
# Epoch 30/50
#
# Epoch 30: val_loss did not improve from 0.06726
# 352/352 - 101s - loss: 0.0667 - val_loss: 0.0677 - 101s/epoch - 287ms/step
# Epoch 31/50
#
# Epoch 31: val_loss improved from 0.06726 to 0.06721, saving model to denoising_model.h5
# 352/352 - 101s - loss: 0.0667 - val_loss: 0.0672 - 101s/epoch - 288ms/step
# Epoch 32/50
#
# Epoch 32: val_loss improved from 0.06721 to 0.06719, saving model to denoising_model.h5
# 352/352 - 101s - loss: 0.0666 - val_loss: 0.0672 - 101s/epoch - 288ms/step
# Epoch 33/50
#
# Epoch 33: val_loss did not improve from 0.06719
# 352/352 - 102s - loss: 0.0667 - val_loss: 0.0674 - 102s/epoch - 289ms/step
# Epoch 34/50
#
# Epoch 34: val_loss did not improve from 0.06719
# 352/352 - 102s - loss: 0.0666 - val_loss: 0.0673 - 102s/epoch - 289ms/step
# Epoch 35/50
#
# Epoch 35: val_loss did not improve from 0.06719
# 352/352 - 105s - loss: 0.0666 - val_loss: 0.0677 - 105s/epoch - 298ms/step
# Epoch 36/50
#
# Epoch 36: val_loss improved from 0.06719 to 0.06716, saving model to denoising_model.h5
# 352/352 - 101s - loss: 0.0666 - val_loss: 0.0672 - 101s/epoch - 288ms/step
# Epoch 37/50
#
# Epoch 37: val_loss did not improve from 0.06716
# 352/352 - 102s - loss: 0.0665 - val_loss: 0.0679 - 102s/epoch - 288ms/step
# Epoch 38/50
#
# Epoch 38: val_loss did not improve from 0.06716
# 352/352 - 102s - loss: 0.0665 - val_loss: 0.0680 - 102s/epoch - 289ms/step
# Epoch 39/50
#
# Epoch 39: val_loss did not improve from 0.06716
# 352/352 - 102s - loss: 0.0664 - val_loss: 0.0676 - 102s/epoch - 288ms/step
# Epoch 40/50
#
# Epoch 40: val_loss improved from 0.06716 to 0.06696, saving model to denoising_model.h5
# 352/352 - 102s - loss: 0.0664 - val_loss: 0.0670 - 102s/epoch - 290ms/step
# Epoch 41/50
#
# Epoch 41: val_loss improved from 0.06696 to 0.06688, saving model to denoising_model.h5
# 352/352 - 106s - loss: 0.0663 - val_loss: 0.0669 - 106s/epoch - 301ms/step
# Epoch 42/50
#
# Epoch 42: val_loss improved from 0.06688 to 0.06685, saving model to denoising_model.h5
# 352/352 - 105s - loss: 0.0663 - val_loss: 0.0668 - 105s/epoch - 299ms/step
# Epoch 43/50
#
# Epoch 43: val_loss improved from 0.06685 to 0.06683, saving model to denoising_model.h5
# 352/352 - 102s - loss: 0.0663 - val_loss: 0.0668 - 102s/epoch - 289ms/step
# Epoch 44/50
#
# Epoch 44: val_loss improved from 0.06683 to 0.06680, saving model to denoising_model.h5
# 352/352 - 103s - loss: 0.0663 - val_loss: 0.0668 - 103s/epoch - 291ms/step
# Epoch 45/50
#
# Epoch 45: val_loss improved from 0.06680 to 0.06680, saving model to denoising_model.h5
# 352/352 - 103s - loss: 0.0662 - val_loss: 0.0668 - 103s/epoch - 293ms/step
# Epoch 46/50
#
# Epoch 46: val_loss improved from 0.06680 to 0.06670, saving model to denoising_model.h5
# 352/352 - 102s - loss: 0.0663 - val_loss: 0.0667 - 102s/epoch - 290ms/step
# Epoch 47/50
#
# Epoch 47: val_loss did not improve from 0.06670
# 352/352 - 102s - loss: 0.0662 - val_loss: 0.0670 - 102s/epoch - 289ms/step
# Epoch 48/50
#
# Epoch 48: val_loss improved from 0.06670 to 0.06665, saving model to denoising_model.h5
# 352/352 - 102s - loss: 0.0662 - val_loss: 0.0667 - 102s/epoch - 290ms/step
# Epoch 49/50
#
# Epoch 49: val_loss did not improve from 0.06665
# 352/352 - 105s - loss: 0.0661 - val_loss: 0.0667 - 105s/epoch - 299ms/step
# Epoch 50/50
#
# Epoch 50: val_loss improved from 0.06665 to 0.06665, saving model to denoising_model.h5
# 352/352 - 104s - loss: 0.0661 - val_loss: 0.0666 - 104s/epoch - 294ms/step

# %%
#loading best performance model
from keras.models import load_model
autoencoder = load_model('denoising_model.h5')
autoencoder.summary()
# Out:
# Model: "Denoising_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 28, 28, 32)        320
#
#  batch_normalization (Batch  (None, 28, 28, 32)        128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        9248
#
#  batch_normalization_1 (Bat  (None, 14, 14, 32)        128
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 32)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 32)          9248
#
#  batch_normalization_2 (Bat  (None, 7, 7, 32)          128
#  chNormalization)
#
#  up_sampling2d (UpSampling2  (None, 14, 14, 32)        0
#  D)
#
#  conv2d_3 (Conv2D)           (None, 14, 14, 32)        9248
#
#  batch_normalization_3 (Bat  (None, 14, 14, 32)        128
#  chNormalization)
#
#  up_sampling2d_1 (UpSamplin  (None, 28, 28, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 1)         289
#
# =================================================================
# Total params: 28865 (112.75 KB)
# Trainable params: 28609 (111.75 KB)
# Non-trainable params: 256 (1.00 KB)
# _________________________________________________________________

# %%
def visualize_data(data, row, column):
    data = data.reshape(data.shape[0], 28,28)
    count = 0
    fig, axes = plt.subplots(row, column, figsize = (16,4))
    for i in range(row):
        for j in range(column):
            axes[i,j].imshow(data[count], cmap = 'gray')
            count+=1

# %%
visualize_data(X_test_noise[:20], 2,10)

# %%
pred = autoencoder.predict(X_test_noise[:20])
pred.shape
# Out:
# 1/1 [==============================] - 1s 781ms/step
# (20, 28, 28, 1)

# %%
visualize_data(pred, 2, 10)
